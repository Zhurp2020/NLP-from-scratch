# %% [markdown]
# # Thomas Calculus
# ## Chapter 1 Functions
# ### 1.1 Functions and their graphs
# #### Functions
# #### Finding Formulas for Functions
# #### Functions and Graphs
# 15. $f(x) = 5 - 2x$
#    $D: R$

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-5,5,0.1) 
y = np.arange(-5,5,0.1)

# %%
def f(x):
    return 5 - 2 * x
plt.plot(x,f(x))

# %% [markdown]
# 16. $f(x) = 1 - 2x - x^2$
#    $D: R$

# %%
def f(x):
    return 1 - 2 * x - x**2
plt.plot(x,f(x))

# %% [markdown]
# 17. $g(x) = \sqrt{|x|}$
#    $D: R$

# %%
def g(x):
    return np.sqrt(abs(x)) 
plt.plot(x,g(x))

# %% [markdown]
# 18. $g(x) = \sqrt{-x}$
#    $D: (-\infty,0]$

# %%
x1 = np.arange(-10,0,0.1)
def g(x):
    return np.sqrt(0-x)
plt.plot(x1,g(x1))

# %% [markdown]
# 19. $F(t) = \dfrac{t}{|t|}$
#    $D: (-\infty,0)\cup(0,+\infty)$

# %%
x2 = np.arange(-5,0,0.1)
x3 = np.arange(0.1,5,0.1)
def F(x):
    return x/abs(x)
plt.plot(x2,F(x2),x3,F(x3))

# %% [markdown]
# 20. $G(t) = \dfrac{1}{|t|}$
#    $D: (-\infty,0)\cup(0,+\infty)$

# %%
def G(x):
    return 1/abs(x)
plt.plot(x2,G(x2),x3,G(x3))

# %% [markdown]
# 23. Graph the following equations and explain why they are not
# graphs of functions of $x$.
#    a. $|y| = x$ b. $y^2 = x^2$

# %%
X,Y = np.meshgrid(x,y)
za = abs(Y) - X
zb = np.power(Y,2) - np.power(X,2)
fig,(ax1,ax2) = plt.subplots(2,1,sharex= True)
ax1.contour(X,Y,za,0)
ax2.contour(X,Y,zb,0)
fig.show()

# %% [markdown]
# 24. Graph the following equations and explain why they are not
# graphs of functions of $x$.
#    a. $|x| + |y| = 1$ b. $|x + y| = 1$

# %%
za = abs(X) + abs(Y) -1
zb = abs(X + Y) - 1
fig,(ax1,ax2) = plt.subplots(2,1,sharex= True)
ax1.contour(X,Y,za,0)
ax2.contour(X,Y,zb,0)
fig.show()

# %% [markdown]
# #### Piecewise-Defined Functions
# Graph the functions in Exercises 25–28.
#
# 25. $f(x) = \left\{\begin{aligned} x &, 0 \le x \le 1\\ 2 - x &, 1 < x \le 2\end{aligned}\right.$

# %%
x1 = np.arange(0,1.1,0.1)
x2 = np.arange(1,2,0.1)
def f1(x):
    return x
def f2(x):
    return 2 - x
plt.plot(x1,f1(x1),x2,f2(x2))

# %% [markdown]
# 26. $g(x) = \left\{\begin{aligned} 1 - x &, 0 \le x \le 1\\ 2 - x &, 1 < x \le 2\end{aligned}\right.$

# %%
x1 = np.arange(0,1.1,0.1)
x2 = np.arange(1,2,0.1)
def f1(x):
    return 1 - x
def f2(x):
    return 2 - x
plt.plot(x1,f1(x1),x2,f2(x2))

# %% [markdown]
# 27. $F(x) = \left\{\begin{aligned} 4 - x &, x \le 1\\ x^2 + 2x &, x \ge 1\end{aligned}\right.$

# %%
x1 = np.arange(-5,1.1,0.1)
x2 = np.arange(1,6,0.1)
def f1(x):
    return 4 - x
def f2(x):
    return x ** 2 + 2 * x
plt.plot(x1,f1(x1),x2,f2(x2))

# %% [markdown]
# 28. $G(x) = \left\{\begin{aligned} \dfrac{1}{x} &, x < 0\\ x &, x \ge 0\end{aligned}\right.$

# %%
x1 = np.arange(-5,0,0.01)
x2 = np.arange(0,5,0.1)
def f1(x):
    return 1 / x
def f2(x):
    return x
plt.plot(x1,f1(x1),x2,f2(x2))

# %% [markdown]
# #### The Greatest and Least Integer Functions
# 36. Graph the function, Why is $f(x)$ called the integer part of x?
# $$
# f(x) = \left\{\begin{aligned}
#    \lfloor x \rfloor , x \ge 0  \\
#    \lceil  x \rceil  , x <   0
# \end{aligned}
# \right.
# $$

# %%
def f(x):
    if x >= 0 :
        return np.floor(x)
    else :
        return np.ceil(x)
plt.plot(x,[f(t) for t in x])

# %% [markdown]
# #### Increasing and Decreasing Functions
# Graph the functions in Exercises 37–46. What symmetries, if any, do
# the graphs have? Specify the intervals over which the function is
# increasing and the intervals where it is decreasing.
#
# 37. $y = -x^3$

# %%
def f(x):
    return 0 - x ** 3
plt.plot(x,f(x))

# %% [markdown]
# 38. $y = -\dfrac{1}{x^2}$

# %%
x1 = np.arange(-5,0,0.2) 
x2 = np.arange(0.2,5.2,0.2) 
def f(x):
    return 0 - (1 / x ** 2)
plt.plot(x1,f(x1),x2,f(x2))

# %% [markdown]
# 39. $y = -\dfrac{1}{x}$

# %%
x1 = np.arange(-5,0,0.1) 
x2 = np.arange(0,5.1,0.1) 
def f(x):
    return 0 - 1 / x
plt.plot(x1,f(x1),x2,f(x2))

# %% [markdown]
# 40. $y = \dfrac{1}{|x|}$

# %%
x1 = np.arange(-5,0,0.1) 
x2 = np.arange(0,5.1,0.1) 
def f(x):
    return 0 - 1 / abs(x)
plt.plot(x1,f(x1),x2,f(x2))

# %% [markdown]
# 41. $y = \sqrt{|x|}$

# %%
def f(x):
    return np.sqrt(abs(x))
plt.plot(x,f(x))

# %% [markdown]
# 42. $y = \sqrt{-x}$

# %%
x1 = np.arange(-10,0,0.1)
def f(x):
    return np.sqrt(0 -x)
plt.plot(x1,f(x1))

# %% [markdown]
# 43. $y = \dfrac{x^3}{8}$

# %%
def f(x):
    return (x ** 3) / 8
plt.plot(x,f(x))

# %% [markdown]
# 44. $y = -4\sqrt{x}$

# %%
x1 = np.arange(0,10,0.1)
def f(x):
    return -4 * np.sqrt(x)
plt.plot(x1,f(x1))

# %% [markdown]
# 45. $y = -x^\frac{3}{2}$

# %%
x1 = np.arange(0,10,0.1)
def f(x):
    return 0 - (x ** (3 / 2)) 
plt.plot(x1,f(x1))

# %% [markdown]
# 46. $y = (-x)^\frac{3}{2}$

# %%
x1 = np.arange(-10,0,0.1)
def f(x):
    return (0 - x) ** (3 / 2)
plt.plot(x1,f(x1))
