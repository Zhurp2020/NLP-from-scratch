# %% [markdown]
# # Thomas Calculus
# ## Chapter 14 Partial Derivatives
# ### 14.1 Functions of Several Variables
# #### Domain, Range, and Level Curves
# #### Matching Surfaces with Level Curves
# #### Functions of Two Variables
# Display the values of the functions in Exercises 37–48 in two ways: (a) by sketching the surface $z=f(x,y)$ and (b) by drawing an assortment of level curves in the function’s domain. Label each level curve with its function value.
#
# 37. $f(x,y)=y^2$

# %%
import numpy as np
#from scipy.integrate import odeint
import matplotlib.pyplot as plt
class FunctionPlotter():
    def __init__(self,function,
    domain=0,CustomDomain=None,
    ticks=[np.linspace(-5,5,5),np.linspace(-5,5,5)],
    lim=[(-5,5),(-5,5)]):
        '''
        params: 
        function: the function to be plotted
        domain: the range of x 
                default: 0: [-5,5]
                1:[0,10]
                2:[-10,0]
                or other array like value of x
        '''
        self.function = function
        self.xticks, self.yticks = ticks[0],ticks[1]
        self.xlim,self.ylim = lim[0],lim[1]
        if domain == 0 :
            self.x = np.linspace(-5,5,101)
        elif domain == 1:
            self.x = np.linspace(0,10,101)
        elif domain == 2:
            self.x = np.linspace(-10,0,101)
        elif domain == 3:
            self.x = CustomDomain
    def canvas(self):
        self.fig,self.ax = plt.subplots()
        self.ax.spines["left"].set_position(("axes", 0.5))
        self.ax.spines["bottom"].set_position(("axes", 0.5))
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        #self.ax.plot(1, 0, ">k", transform=self.ax.get_yaxis_transform(), clip_on=False)
        #self.ax.plot(0, 1, "^k", transform=self.ax.get_xaxis_transform(), clip_on=False)
        self.ax.set_xlabel('x',x=1)
        self.ax.set_ylabel('y',y=1)
        self.ax.set_xticks(self.xticks)
        self.ax.set_yticks(self.yticks)
        self.ax.set_xlim(self.xlim)
        self.ax.set_ylim(self.ylim)
    def plot(self):
        self.y = self.function(self.x)
        self.canvas()
        self.ax.plot(self.x,self.y)
    def PlotMultiFunction(self):
        self.y = [function(self.x) for function in self.function]
        self.canvas()
        for i in range(len(self.function)):
            self.ax.plot(self.x,self.y[i],label='f({})'.format(i+1))
            self.ax.legend()
    def PlotContour(self):
        self.y = self.x
        X,Y = np.meshgrid(self.x,self.y)
        self.canvas()
        self.ax.contour(X,Y,self.function(X,Y),0)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
def f(x,y):
    return y**2 - 1
def f1(x,y):
    return y**2 - 2
a = FunctionPlotter(f)
a.PlotContour()
a.function = f1
X,Y = np.meshgrid(a.x,a.y)
a.ax.contour(X,Y,a.function(X,Y),0)

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100) 
X,Y = np.meshgrid(x,y)
Z =Y**2
ax = plt.axes(projection = '3d')
ax.plot_surface(X,Y,Z)

# %% [markdown]
# #### Finding Level Curves
# In Exercises 49–52, find an equation for and sketch the graph of the level curve of the function $f(x,y)$ that passes through the given point.
#
# 49. $f(x,y) = 16 - x^2 - y^2,(2\sqrt{2},\sqrt{2})$
#     $16 -x^2 - y^2 = 6$

# %%
def f(x,y):
    return 6 - x**2 - y**2
FunctionPlotter(f).PlotContour()

# %% [markdown]
# #### Sketching Level Surfaces
# In Exercises 53–60, sketch a typical level surface for the function.
#
# 53. $f(x,y,z)=x^2+y^2+z^2$

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100) 
X,Y = np.meshgrid(x,y)
Z =np.sqrt(60-X**2 - Y**2)
ax = plt.axes(projection = '3d')
ax.plot_surface(X,Y,Z)

# %% [markdown]
# #### Finding Level Surfaces
# In Exercises 61–64, find an equation for the level surface of the function through the given point.
#
# 61. $f(x, y, z) = \sqrt{x - y} - \ln z, (3, -1, 1)$
#     $\sqrt{x - y} - \ln z = 2$

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100) 
X,Y = np.meshgrid(x,y)
Z =np.e**(np.sqrt(X - Y) - 2)
ax = plt.axes(projection = '3d')
ax.plot_surface(X,Y,Z)
# Out:
# <ipython-input-8-09009936aa5e>:4: RuntimeWarning: invalid value encountered in sqrt
#   Z =np.e**(np.sqrt(X - Y) - 2)
# <ipython-input-8-09009936aa5e>:6: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   ax.plot_surface(X,Y,Z)

# %% [markdown]
# #### COMPUTER EXPLORATIONS
# Use a CAS to perform the following steps for each of the functions in Exercises 69–72.
# a. Plot the surface over the given rectangle.
# b. Plot several level curves in the rectangle.
# c. Plot the level curve of $f$ through the given point.
#
# 69. $f(x,y) = x\sin\dfrac{y}{2} + y\sin 2x,0 \le x \le 5\pi, 0 \le y \le 5\pi, P(3\pi,\pi)$

# %%
def f(x,y):
    return x*np.sin(y/2) + y*np.sin(2*x)
def f1(x,y):
    return x*np.sin(y/2) + y*np.sin(2*x) - 3*np.pi
a = FunctionPlotter(f,3,np.linspace(0,5*np.pi,101),ticks=[np.linspace(-5*np.pi,5*np.pi,5),np.linspace(-5*np.pi,5*np.pi,5)],lim=[(-5*np.pi,5*np.pi),(-5*np.pi,5*np.pi)])
a.canvas()
a.function = f1
X,Y = np.meshgrid(a.x,a.x)
a.ax.contour(X,Y,a.function(X,Y),0)
a.function = f
X,Y = np.meshgrid(a.x,a.x)
a.ax.contour(X,Y,a.function(X,Y),0)

# %% [markdown]
# ### 14.5 Directional Derivatives and Gradient Vectors
# #### Calculating Gradients
# In Exercises 1–6, find the gradient of the function at the given point. Then sketch the gradient together with the level curve that passes through the point.
#
# 1. $f(x, y) = y - x, (2, 1)$

# %%
def f(x):
    return x +1
def g(x):
    return -x + 3
FunctionPlotter([f,g]).PlotMultiFunction()

# %% [markdown]
# #### Finding Directional Derivatives
# #### Tangent Lines to Level Curves
# In Exercises 25–28, sketch the curve $f(x, y) = c$ together with $\nabla f$ and the tangent line at the given point. Then write an equation for the tangent line.
#
# 25. $x^2 + y^2 = 4,(\sqrt{2},\sqrt{2})$

# %%
def f(x,y):
    return x**2 + y**2 -4
def g(x):
    return x
a = FunctionPlotter(f)
a.PlotContour()
a.ax.plot(a.x,g(a.x))

# %% [markdown]
# #### COMPUTER EXPLORATIONS
# In Exercises 71–76, you will explore functions to identify their local extrema. Use a CAS to perform the following steps:
# a. Plot the function over the given rectangle.
# b. Plot some level curves in the rectangle.
# c. Calculate the function’s first partial derivatives and use the CAS equation solver to find the critical points. How do the critical points relate to the level curves plotted in part (b)?  Which critical points, if any, appear to give a saddle point?Give reasons for your answer.
# d. Calculate the function’s second partial derivatives and find the discriminant $f_{xx}f_{yy} - f_{xy}^2$
# e. Using the max-min tests, classify the critical points found in part (c). Are your findings consistent with your discussion in part (c)?
#
# 71. $f(x, y) = x^2 + y^3 - 3xy, -5 \le x \le 5, -5 \le y \le 5$

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100) 
X,Y = np.meshgrid(x,y)
Z = X**2 + Y**3 -3*X*Y
ax = plt.axes(projection = '3d')
ax.plot_surface(X,Y,Z)

# %%
def f(x,y):
    return x**2 + y**3 -3*x*y
def f1(x,y):
    return x**2 + y**3 -3*x*y -1
def f2(x,y):
    return x**2 + y**3 -3*x*y -2 
a = FunctionPlotter(f)
a.canvas()
a.function = f1
X,Y = np.meshgrid(a.x,a.x)
a.ax.contour(X,Y,a.function(X,Y),0)
a.function = f
X,Y = np.meshgrid(a.x,a.x)
a.ax.contour(X,Y,a.function(X,Y),0)
a.function = f2
X,Y = np.meshgrid(a.x,a.x)
a.ax.contour(X,Y,a.function(X,Y),0)
